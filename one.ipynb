# %%
import numpy as np
import sounddevice as sd

f = 50
fs = 8000
t = np.linspace(0,1,fs)
x = np.sin(2*np.pi*f*t)
sd.play(x,fs)

# %%
from scipy.io import wavfile
fs, x0 = wavfile.read('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 from scipy.io import wavfile
# ----> 2 fs, x0 = wavfile.read('')
#
# File c:\Users\thain\anaconda3\Lib\site-packages\scipy\io\wavfile.py:647, in read(filename, mmap)
#     645     mmap = False
#     646 else:
# --> 647     fid = open(filename, 'rb')
#     649 try:
#     650     file_size, is_big_endian = _read_riff_chunk(fid)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
from scipy.io.wavfile import write

freq = 84100

duration = 5

recording = sd.rec(int(duration * freq), samplerate=freq, channels=2)

sd.wait()

sd.play(recording,freq)
sd.wait()

write("recording0.wav",freq,recording)

# %%
import numpy as up 
import matplotlib.pyplot as plt

t= np.linspace(0,1,1000)
Amp = 5
freq = 5
phase = 0
phase2 = np.pi/3*2

x=Amp*np.sin(2*np.pi*freq*t+phase)
x2=Amp*np.sin(2*np.pi*freq*t+phase2)

plt.plot(t,x)
plt.plot(t,x2)
# plt.plot(t,x)
plt.xlabel('Time (t)')
plt.ylabel('Amplitude (V)')
plt.title('$\Phi ={}^\circ $'.format(phase))
plt.tight_layout()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\P'
# <>:18: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\thain\AppData\Local\Temp\ipykernel_23996\3630617220.py:18: SyntaxWarning: invalid escape sequence '\P'
#   plt.title('$\Phi ={}^\circ $'.format(phase))

# %%
import numpy as up 
import matplotlib.pyplot as plt

t= np.linspace(0,1,1000)
Amp = 5
freq = 5
phase = 0
phase2 = np.pi/3*2

x=Amp*np.sin(2*np.pi*freq*t+phase)
x2=Amp*np.sin(2*np.pi*freq*t+phase2)

x3 = np.singn(np.sin(2* np.pi * freq * t))
# x4 = np.sin(2*np.pi * freq *t)

plt.plot(t,x)
plt.plot(t,x2)
# plt.plot(t,x3)
plt.xlabel('Time (t)')
plt.ylabel('Amplitude (V)')
plt.title('$\Phi ={}^\circ $'.format(phase))
plt.tight_layout()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\P'
# <>:21: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\thain\AppData\Local\Temp\ipykernel_23996\3347212491.py:21: SyntaxWarning: invalid escape sequence '\P'
#   plt.title('$\Phi ={}^\circ $'.format(phase))
# C:\Users\thain\AppData\Local\Temp\ipykernel_23996\3347212491.py:21: SyntaxWarning: invalid escape sequence '\P'
#   plt.title('$\Phi ={}^\circ $'.format(phase))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 13
#      10 x=Amp*np.sin(2*np.pi*freq*t+phase)
#      11 x2=Amp*np.sin(2*np.pi*freq*t+phase2)
# ---> 13 x3 = np.singn(np.sin(2* np.pi * freq * t))
#      14 # x4 = np.sin(2*np.pi * freq *t)
#      16 plt.plot(t,x)
#
# File c:\Users\thain\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
# ...

# %%
#5


noise = np.random.narmal(0,0.5, fs)
combinded_signal = sinc_wave+noise

ple=t.figure(figsixe=  (10,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 #5
# ----> 3 combinded_signal = sine_wave+noise
#       5 ple=t.figure(figsixe=  (10,6))
#
# NameError: name 'sine_wave' is not defined
